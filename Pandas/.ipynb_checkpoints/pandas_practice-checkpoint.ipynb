# %% [markdown]
# # Pandas

# %%
import pandas as pd
df = pd.read_csv('Ball_by_Ball.csv')
# Out:
# /tmp/ipykernel_496151/2113578991.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Ball_by_Ball.csv')

# %%
df.head(7)
#first 7 row
# Out:
#    Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  Team_Bowling_Id  \
# 0    335987           1        1        1                1                2
# 1    335987           1        1        2                1                2
# 2    335987           1        1        3                1                2
# 3    335987           1        1        4                1                2
# 4    335987           1        1        5                1                2
# 5    335987           1        1        6                1                2
# 6    335987           1        1        7                1                2
#
#    Striker_Id  Striker_Batting_Position  Non_Striker_Id  Bowler_Id  \
# 0           1                         1               2         14
# 1           2                         2               1         14
# 2           2                         2               1         14
# 3           2                         2               1         14
# ...

# %%
df.tail(6)
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 136584    981024           2       20        1                2
# 136585    981024           2       20        2                2
# 136586    981024           2       20        3                2
# 136587    981024           2       20        4                2
# 136588    981024           2       20        5                2
# 136589    981024           2       20        6                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 136584               11         434                         8             369
# 136585               11         369                         6             434
# 136586               11         369                         6             434
# 136587               11         140                         9             369
# 136588               11         369                         6             140
# ...

# %%
# create dataframe from a dictionary
temporary_dictionary = {'col1':[1,2,3,4], 'col2':[5,6,7,8], 'col3':[9,10,11,12]}
new_df = pd.DataFrame.from_dict(temporary_dictionary)

# %%
new_df.head(4)
# Out:
#    col1  col2  col3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
df.columns
# Out:
# Index(['Match_Id', 'Innings_Id', 'Over_Id', 'Ball_Id', 'Team_Batting_Id',
#        'Team_Bowling_Id', 'Striker_Id', 'Striker_Batting_Position',
#        'Non_Striker_Id', 'Bowler_Id', 'Batsman_Scored', 'Extra_Type',
#        'Extra_Runs', 'Player_dissimal_Id', 'Dissimal_Type', 'Fielder_Id'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Match_Id                     int64
# Innings_Id                   int64
# Over_Id                      int64
# Ball_Id                      int64
# Team_Batting_Id              int64
# Team_Bowling_Id              int64
# Striker_Id                   int64
# Striker_Batting_Position     int64
# Non_Striker_Id               int64
# Bowler_Id                    int64
# Batsman_Scored              object
# Extra_Type                  object
# Extra_Runs                  object
# Player_dissimal_Id          object
# Dissimal_Type               object
# Fielder_Id                  object
# dtype: object

# %%
df.describe()
# Out:
#             Match_Id     Innings_Id        Over_Id        Ball_Id  \
# count  136590.000000  136590.000000  136590.000000  136590.000000
# mean   590906.063643       1.482744      10.144593       3.617278
# std    195509.555405       0.501576       5.673822       1.808142
# min    335987.000000       1.000000       1.000000       1.000000
# 25%    419140.000000       1.000000       5.000000       2.000000
# 50%    548353.000000       1.000000      10.000000       4.000000
# 75%    734002.000000       2.000000      15.000000       5.000000
# max    981024.000000       4.000000      20.000000       9.000000
#
#        Team_Batting_Id  Team_Bowling_Id     Striker_Id  \
# count    136590.000000    136590.000000  136590.000000
# mean          5.168951         5.156783     126.643239
# std           3.033943         3.038008     111.078188
# min           1.000000         1.000000       1.000000
# 25%           3.000000         3.000000      35.000000
# ...

# %%
df.describe(include='object')
# Out:
#        Batsman_Scored Extra_Type Extra_Runs Player_dissimal_Id Dissimal_Type  \
# count          136590     136590     136590             136590        136590
# unique             15          6          6                398            10
# top                 0
# freq            42351     130330     130330             131058        131058
#
#        Fielder_Id
# count      136590
# unique        365
# top
# freq       132577

# %%
#filtering columns
df.Match_Id
# Out:
# 0         335987
# 1         335987
# 2         335987
# 3         335987
# 4         335987
#            ...
# 136585    981024
# 136586    981024
# 136587    981024
# 136588    981024
# 136589    981024
# Name: Match_Id, Length: 136590, dtype: int64

# %%
df[['Match_Id', 'Innings_Id']]
# Out:
#         Match_Id  Innings_Id
# 0         335987           1
# 1         335987           1
# 2         335987           1
# 3         335987           1
# 4         335987           1
# ...          ...         ...
# 136585    981024           2
# 136586    981024           2
# 136587    981024           2
# 136588    981024           2
# 136589    981024           2
#
# [136590 rows x 2 columns]

# %%
df.Innings_Id.unique()
# Out:
# array([1, 2, 3, 4])

# %%
df[df['Batsman_Scored']=='6']
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 10        335987           1        2        4                1
# 20        335987           1        4        2                1
# 25        335987           1        4        7                1
# 60        335987           1       10        5                1
# 65        335987           1       11        4                1
# ...          ...         ...      ...      ...              ...
# 136525    981024           2       10        2                2
# 136543    981024           2       13        2                2
# 136558    981024           2       15        5                2
# 136570    981024           2       17        5                2
# 136583    981024           2       19        6                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 10                    2           2                         2               1
# ...

# %%
df[(df['Batsman_Scored']=='0') & (df['Extra_Type']=='legbyes')]
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0         335987           1        1        1                1
# 6         335987           1        1        7                1
# 15        335987           1        3        3                1
# 21        335987           1        4        3                1
# 133       335987           2        2        3                2
# ...          ...         ...      ...      ...              ...
# 136467    981024           2        1        2                2
# 136481    981024           2        3        2                2
# 136576    981024           2       18        5                2
# 136581    981024           2       19        4                2
# 136587    981024           2       20        4                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                     2           1                         1               2
# ...

# %%
# row filtering 
df.iloc[10:60]
# Out:
#     Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  Team_Bowling_Id  \
# 10    335987           1        2        4                1                2
# 11    335987           1        2        5                1                2
# 12    335987           1        2        6                1                2
# 13    335987           1        3        1                1                2
# 14    335987           1        3        2                1                2
# 15    335987           1        3        3                1                2
# 16    335987           1        3        4                1                2
# 17    335987           1        3        5                1                2
# 18    335987           1        3        6                1                2
# 19    335987           1        4        1                1                2
# 20    335987           1        4        2                1                2
# ...

# %% [markdown]
# # Update

# %%
df.isnull().sum()
# Out:
# Match_Id                    0
# Innings_Id                  0
# Over_Id                     0
# Ball_Id                     0
# Team_Batting_Id             0
# Team_Bowling_Id             0
# Striker_Id                  0
# Striker_Batting_Position    0
# Non_Striker_Id              0
# Bowler_Id                   0
# Batsman_Scored              0
# Extra_Type                  0
# Extra_Runs                  0
# Player_dissimal_Id          0
# Dissimal_Type               0
# Fielder_Id                  0
# dtype: int64

# %%
df.drop('Match_Id', axis=1)
# Out:
#         Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  Team_Bowling_Id  \
# 0                1        1        1                1                2
# 1                1        1        2                1                2
# 2                1        1        3                1                2
# 3                1        1        4                1                2
# 4                1        1        5                1                2
# ...            ...      ...      ...              ...              ...
# 136585           2       20        2                2               11
# 136586           2       20        3                2               11
# 136587           2       20        4                2               11
# 136588           2       20        5                2               11
# 136589           2       20        6                2               11
#
#         Striker_Id  Striker_Batting_Position  Non_Striker_Id  Bowler_Id  \
# ...

# %%
df['New_column'] = df['Innings_Id'] + df['Bowler_Id']

# %%
df.head()
# Out:
#    Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  Team_Bowling_Id  \
# 0    335987           1        1        1                1                2
# 1    335987           1        1        2                1                2
# 2    335987           1        1        3                1                2
# 3    335987           1        1        4                1                2
# 4    335987           1        1        5                1                2
#
#    Striker_Id  Striker_Batting_Position  Non_Striker_Id  Bowler_Id  \
# 0           1                         1               2         14
# 1           2                         2               1         14
# 2           2                         2               1         14
# 3           2                         2               1         14
# 4           2                         2               1         14
#
#   Batsman_Scored Extra_Type Extra_Runs Player_dissimal_Id Dissimal_Type  \
# ...

# %%
df.iloc[0,-1] = 100
df.head()
# Out:
#    Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  Team_Bowling_Id  \
# 0    335987           1        1        1                1                2
# 1    335987           1        1        2                1                2
# 2    335987           1        1        3                1                2
# 3    335987           1        1        4                1                2
# 4    335987           1        1        5                1                2
#
#    Striker_Id  Striker_Batting_Position  Non_Striker_Id  Bowler_Id  \
# 0           1                         1               2         14
# 1           2                         2               1         14
# 2           2                         2               1         14
# 3           2                         2               1         14
# 4           2                         2               1         14
#
#   Batsman_Scored Extra_Type Extra_Runs Player_dissimal_Id Dissimal_Type  \
# ...

# %%
# Apply function
df['Extra_Type_counting'] = df['Extra_Type'].apply(lambda x: 'LegBye' if x=='legbyes' else 'No Legbyes')
df[df['Extra_Type_counting']=='LegBye'].head()
# Out:
#      Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  Team_Bowling_Id  \
# 0      335987           1        1        1                1                2
# 6      335987           1        1        7                1                2
# 15     335987           1        3        3                1                2
# 21     335987           1        4        3                1                2
# 133    335987           2        2        3                2                1
#
#      Striker_Id  Striker_Batting_Position  Non_Striker_Id  Bowler_Id  \
# 0             1                         1               2         14
# 6             2                         2               1         14
# 15            1                         1               2         14
# 21            2                         2               1         13
# 133           8                         3               7         84
#
#     Batsman_Scored Extra_Type Extra_Runs Player_dissimal_Id Dissimal_Type  \
# ...

# %%
df.head()
# Out:
#    Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  Team_Bowling_Id  \
# 0    335987           1        1        1                1                2
# 1    335987           1        1        2                1                2
# 2    335987           1        1        3                1                2
# 3    335987           1        1        4                1                2
# 4    335987           1        1        5                1                2
#
#    Striker_Id  Striker_Batting_Position  Non_Striker_Id  Bowler_Id  \
# 0           1                         1               2         14
# 1           2                         2               1         14
# 2           2                         2               1         14
# 3           2                         2               1         14
# 4           2                         2               1         14
#
#   Batsman_Scored Extra_Type Extra_Runs Player_dissimal_Id Dissimal_Type  \
# ...

# %% [markdown]
# # Output & Delete

# %%
df.to_csv('Generated_CSV')

# %%
new_df = df.head()

# %%
new_df.to_json()
# Out:
# '{"Match_Id":{"0":335987,"1":335987,"2":335987,"3":335987,"4":335987},"Innings_Id":{"0":1,"1":1,"2":1,"3":1,"4":1},"Over_Id":{"0":1,"1":1,"2":1,"3":1,"4":1},"Ball_Id":{"0":1,"1":2,"2":3,"3":4,"4":5},"Team_Batting_Id":{"0":1,"1":1,"2":1,"3":1,"4":1},"Team_Bowling_Id":{"0":2,"1":2,"2":2,"3":2,"4":2},"Striker_Id":{"0":1,"1":2,"2":2,"3":2,"4":2},"Striker_Batting_Position":{"0":1,"1":2,"2":2,"3":2,"4":2},"Non_Striker_Id":{"0":2,"1":1,"2":1,"3":1,"4":1},"Bowler_Id":{"0":14,"1":14,"2":14,"3":14,"4":14},"Batsman_Scored":{"0":"0","1":"0","2":"0","3":"0","4":"0"},"Extra_Type":{"0":"legbyes","1":" ","2":"wides","3":" ","4":" "},"Extra_Runs":{"0":"1","1":" ","2":"1","3":" ","4":" "},"Player_dissimal_Id":{"0":" ","1":" ","2":" ","3":" ","4":" "},"Dissimal_Type":{"0":" ","1":" ","2":" ","3":" ","4":" "},"Fielder_Id":{"0":" ","1":" ","2":" ","3":" ","4":" "},"New_column":{"0":100,"1":15,"2":15,"3":15,"4":15},"Extra_Type_Change":{"0":"LegBye","1":"No Legbyes","2":"No Legbyes","3":"No Legbyes","4":"N
# ...

# %%
new_df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Match_Id</th>\n      <th>Innings_Id</th>\n      <th>Over_Id</th>\n      <th>Ball_Id</th>\n      <th>Team_Batting_Id</th>\n      <th>Team_Bowling_Id</th>\n      <th>Striker_Id</th>\n      <th>Striker_Batting_Position</th>\n      <th>Non_Striker_Id</th>\n      <th>Bowler_Id</th>\n      <th>Batsman_Scored</th>\n      <th>Extra_Type</th>\n      <th>Extra_Runs</th>\n      <th>Player_dissimal_Id</th>\n      <th>Dissimal_Type</th>\n      <th>Fielder_Id</th>\n      <th>New_column</th>\n      <th>Extra_Type_Change</th>\n      <th>Extra_Type_counting</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>335987</td>\n      <td>1</td>\n      <td>1</td>\n      <td>1</td>\n      <td>1</td>\n      <td>2</td>\n      <td>1</td>\n      <td>1</td>\n      <td>2</td>\n      <td>14</td>\n      <td>0</td>\n      <td>legbyes</td>\n      <td>1</td>\n      <td></td>\n      
# ...

# %%
# to delete use del df
