# %%
import pandas as pd

# %%
df = pd.read_csv('Ball_by_Ball.csv')
# Out:
# /tmp/ipykernel_494710/3956849848.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Ball_by_Ball.csv')

# %%
df.head(7)
# Out:
#    Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  Team_Bowling_Id  \
# 0    335987           1        1        1                1                2
# 1    335987           1        1        2                1                2
# 2    335987           1        1        3                1                2
# 3    335987           1        1        4                1                2
# 4    335987           1        1        5                1                2
# 5    335987           1        1        6                1                2
# 6    335987           1        1        7                1                2
#
#    Striker_Id  Striker_Batting_Position  Non_Striker_Id  Bowler_Id  \
# 0           1                         1               2         14
# 1           2                         2               1         14
# 2           2                         2               1         14
# 3           2                         2               1         14
# ...

# %%
df.tail(6)
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 136584    981024           2       20        1                2
# 136585    981024           2       20        2                2
# 136586    981024           2       20        3                2
# 136587    981024           2       20        4                2
# 136588    981024           2       20        5                2
# 136589    981024           2       20        6                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 136584               11         434                         8             369
# 136585               11         369                         6             434
# 136586               11         369                         6             434
# 136587               11         140                         9             369
# 136588               11         369                         6             140
# ...

# %%
df.
